# %%
import pandas as pd

# %%
df = pd.read_csv(r'/Users/vishwa/Desktop/EEG/data2.csv')

# %%
df.head()
# Out:
#      name  hearts      TRP1  Question no      TRP2      TRP3      TRP4  \
# 0  gautam       5  0.212639           13  0.103793  0.188616  0.044259
# 1  gautam       5  0.030412           11  0.026436  0.028877  0.028846
# 2  gautam       5  0.109850           39  0.107796  0.107742  0.086027
# 3  gautam       5  0.061227           38  0.021576  0.062308  0.038776
# 4  gautam       5  0.015245           10  0.038250  0.015673  0.010675
#
#       TRP11     TRP12      ARP1  ...  TPA12  TPA2  TPA3  TPA4  TRPA1  TRPA11  \
# 0  0.070351  0.116575  0.030169  ...    NaN   NaN   NaN   NaN    NaN     NaN
# 1  0.027433  0.021008  0.029668  ...    NaN   NaN   NaN   NaN    NaN     NaN
# 2  0.095648  0.127854  0.008424  ...    NaN   NaN   NaN   NaN    NaN     NaN
# 3  0.053106  0.036498  0.050657  ...    NaN   NaN   NaN   NaN    NaN     NaN
# 4  0.043753  0.021831  0.015099  ...    NaN   NaN   NaN   NaN    NaN     NaN
#
#    TRPA12  TRPA2  TRPA3  TRPA4
# 0     NaN    NaN    NaN    NaN
# ...

# %%
df.columns
# Out:
# Index(['name', 'hearts', 'TRP1', 'Question no', 'TRP2', 'TRP3', 'TRP4',
#        'TRP11', 'TRP12', 'ARP1', 'ARP2', 'ARP3', 'ARP4', 'ARP11', 'ARP12',
#        'BRP1', 'BRP2', 'BRP3', 'BRP4', 'BRP11', 'BRP12', 'APA1', 'APA2',
#        'APA3', 'APA4', 'APA5', 'APA6', 'APA7', 'APA8', 'APA9', 'APA10',
#        'APA11', 'APA12', 'APA13', 'APA14', 'APA15', 'APA16', 'APA17', 'APA18',
#        'APA19', 'APA20', 'APA21', 'BRPA2', 'BRPA3', 'BRPA4', 'TPA1', 'TPA11',
#        'TPA12', 'TPA2', 'TPA3', 'TPA4', 'TRPA1', 'TRPA11', 'TRPA12', 'TRPA2',
#        'TRPA3', 'TRPA4'],
#       dtype='object')

# %%
df.shape
# Out:
# (1096, 57)

# %%
df[['Question no','hearts','TPA1']][100:200]
# Out:
#      Question no  hearts  TPA1
# 100            1       4   NaN
# 101            6       4   NaN
# 102           33       4   NaN
# 103           26       4   NaN
# 104           30       4   NaN
# 105           34       4   NaN
# 106           20       4   NaN
# 107           36       4   NaN
# 108           23       4   NaN
# 109           12       4   NaN
# 110           11       4   NaN
# 111           38       4   NaN
# 112           10       4   NaN
# 113           15       4   NaN
# 114           17       4   NaN
# 115            8       4   NaN
# 116            9       4   NaN
# 117           42       4   NaN
# 118           43       4   NaN
# 119           40       4   NaN
# 120           33       4   NaN
# 121           32       4   NaN
# 122           24       4   NaN
# 123           36       4   NaN
# 124           23       4   NaN
# 125           14       4   NaN
# 126            9       4   NaN
# 127           42       4   NaN
# 128            4       4   NaN
# ...

# %%
list= ['APA1', 'APA11',
       'APA12', 'APA2', 'APA3', 'APA4', 'ARPA1', 'ARPA11', 'ARPA12', 'ARPA2',
       'ARPA3', 'ARPA4', 'BPA1', 'BPA11', 'BPA12', 'BPA2', 'BPA3', 'BPA4',
       'BRPA1', 'BRPA11', 'BRPA12', 'BRPA2', 'BRPA3', 'BRPA4', 'TPA1', 'TPA11',
       'TPA12', 'TPA2', 'TPA3', 'TPA4', 'TRPA1', 'TRPA11', 'TRPA12', 'TRPA2',
       'TRPA3', 'TRPA4']
len(list)
list[0]
# Out:
# 'APA1'

# %%
#for i in range(len(list)):
df.fillna(df.mean()['TPA1'])
# Out:
#             name  hearts      TRP1  Question no      TRP2      TRP3      TRP4  \
# 0         gautam       5  0.212639           13  0.103793  0.188616  0.044259
# 1         gautam       5  0.030412           11  0.026436  0.028877  0.028846
# 2         gautam       5  0.109850           39  0.107796  0.107742  0.086027
# 3         gautam       5  0.061227           38  0.021576  0.062308  0.038776
# 4         gautam       5  0.015245           10  0.038250  0.015673  0.010675
# 5         gautam       5  0.000800            8  0.003967  0.000255  0.001628
# 6         gautam       5  0.203975            4  0.089048  0.227372  0.060597
# 7         gautam       5  0.226900            5  0.109448  0.263023  0.058818
# 8         gautam       5  0.250208           27  0.197891  0.181709  0.115160
# 9         gautam       5  0.113421           31  0.177182  0.065856  0.100115
# 10        gautam       5  0.156469           37  0.084170  0.248645  0.175336
# ...

# %%
df[['Question no','hearts','TPA1']][100:200]
# Out:
#      Question no  hearts  TPA1
# 100            1       4   NaN
# 101            6       4   NaN
# 102           33       4   NaN
# 103           26       4   NaN
# 104           30       4   NaN
# 105           34       4   NaN
# 106           20       4   NaN
# 107           36       4   NaN
# 108           23       4   NaN
# 109           12       4   NaN
# 110           11       4   NaN
# 111           38       4   NaN
# 112           10       4   NaN
# 113           15       4   NaN
# 114           17       4   NaN
# 115            8       4   NaN
# 116            9       4   NaN
# 117           42       4   NaN
# 118           43       4   NaN
# 119           40       4   NaN
# 120           33       4   NaN
# 121           32       4   NaN
# 122           24       4   NaN
# 123           36       4   NaN
# 124           23       4   NaN
# 125           14       4   NaN
# 126            9       4   NaN
# 127           42       4   NaN
# 128            4       4   NaN
# ...

# %%
df=df.fillna(df.mean())

# %%
df[['Question no','hearts','TPA1']][100:200]
# Out:
#      Question no  hearts        TPA1
# 100            1       4  257.566306
# 101            6       4  257.566306
# 102           33       4  257.566306
# 103           26       4  257.566306
# 104           30       4  257.566306
# 105           34       4  257.566306
# 106           20       4  257.566306
# 107           36       4  257.566306
# 108           23       4  257.566306
# 109           12       4  257.566306
# 110           11       4  257.566306
# 111           38       4  257.566306
# 112           10       4  257.566306
# 113           15       4  257.566306
# 114           17       4  257.566306
# 115            8       4  257.566306
# 116            9       4  257.566306
# 117           42       4  257.566306
# 118           43       4  257.566306
# 119           40       4  257.566306
# 120           33       4  257.566306
# 121           32       4  257.566306
# 122           24       4  257.566306
# 123           36       4  257.566306
# ...

# %%
export_csv = df.to_csv(r'/Users/vishwa/Desktop/EEG/data3.csv',index=None,header=True)

# %%
import pandas as pd
df = pd.read_csv(r'/Users/vishwa/Desktop/EEG/data2.csv')

# %%
df.head()
# Out:
#      name  hearts      TRP1  Question no      TRP2      TRP3      TRP4  \
# 0  gautam       5  0.212639           13  0.103793  0.188616  0.044259
# 1  gautam       5  0.030412           11  0.026436  0.028877  0.028846
# 2  gautam       5  0.109850           39  0.107796  0.107742  0.086027
# 3  gautam       5  0.061227           38  0.021576  0.062308  0.038776
# 4  gautam       5  0.015245           10  0.038250  0.015673  0.010675
#
#       TRP11     TRP12      ARP1  ...  TPA12  TPA2  TPA3  TPA4  TRPA1  TRPA11  \
# 0  0.070351  0.116575  0.030169  ...    NaN   NaN   NaN   NaN    NaN     NaN
# 1  0.027433  0.021008  0.029668  ...    NaN   NaN   NaN   NaN    NaN     NaN
# 2  0.095648  0.127854  0.008424  ...    NaN   NaN   NaN   NaN    NaN     NaN
# 3  0.053106  0.036498  0.050657  ...    NaN   NaN   NaN   NaN    NaN     NaN
# 4  0.043753  0.021831  0.015099  ...    NaN   NaN   NaN   NaN    NaN     NaN
#
#    TRPA12  TRPA2  TRPA3  TRPA4
# 0     NaN    NaN    NaN    NaN
# ...

# %%
# Duplicates have been removed
# Considering the case 
train_data = df.iloc[516:,:]


# because all the data is combined according to the rating
train_data = train_data.sample(frac=1).reset_index(drop=True)

train_data
# Out:
#            name  hearts      TRP1  Question no      TRP2      TRP3      TRP4  \
# 0         anish       3  0.320077           40  0.229739  0.097748  0.162222
# 1       ahilesh       1  0.148384           22  0.170044  0.212229  0.189096
# 2      bhargavi       4  0.067000           25  0.044317  0.146206  0.036293
# 3        adarsh       5  0.035465            9  0.145032  0.097796  0.117826
# 4         anish       2  0.120537           24  0.074448  0.221055  0.068043
# 5         anish       4  0.022559            4  0.053433  0.016681  0.044853
# 6      bhargavi       2  0.052961           34  0.042307  0.051486  0.020700
# 7        ananay       4  0.064107           32  0.035712  0.066926  0.125682
# 8         anish       4  0.006857           42  0.008689  0.009758  0.021576
# 9        nikhil       2  0.220063           41  0.157563  0.211370  0.237143
# 10   hrishikesh       3  0.405026           41  0.258517  0.438316  0.280701
# ...

# %%
# since our data is not in similar range, Eg: Question No. and TRP2
# Normalizing the data

# Standard normalization using the data
# We do not need the data of everyone while processing

# NAN values have been eliminated


X = train_data.iloc[:,2:]
Y = train_data.iloc[:,1]

# %%
X.drop(['Question no'],axis =1)
# Out:
#          TRP1      TRP2      TRP3      TRP4     TRP11     TRP12      ARP1  \
# 0    0.320077  0.229739  0.097748  0.162222  0.119641  0.121934  0.172505
# 1    0.148384  0.170044  0.212229  0.189096  0.291597  0.258634  0.069784
# 2    0.067000  0.044317  0.146206  0.036293  0.108800  0.074852  0.006121
# 3    0.035465  0.145032  0.097796  0.117826  0.124597  0.127680  0.023788
# 4    0.120537  0.074448  0.221055  0.068043  0.199570  0.114715  0.081501
# 5    0.022559  0.053433  0.016681  0.044853  0.144016  0.030234  0.019144
# 6    0.052961  0.042307  0.051486  0.020700  0.010906  0.098828  0.000987
# 7    0.064107  0.035712  0.066926  0.125682  0.047673  0.085944  0.319065
# 8    0.006857  0.008689  0.009758  0.021576  0.055821  0.074364  0.001791
# 9    0.220063  0.157563  0.211370  0.237143  0.091457  0.236260  0.123324
# 10   0.405026  0.258517  0.438316  0.280701  0.187806  0.128338  0.158818
# 11   0.201174  0.158626  0.149833  0.344539  0.115107  0.081225  0.061198
# ...

# %%
Y.head()
# Out:
# 0    3
# 1    1
# 2    4
# 3    5
# 4    2
# Name: hearts, dtype: int64

# %%
#from sklearn.preprocessing import StandardScaler

#scaler = StandardScaler() 
# using mean/ standard deviation for normalization
#X= scaler.fit_transform(X)

# till BRP 12 we have all values so will only be considering those
# first we need to split the data
# 5 class or 3 class classification - CONFIRM

# ritchieng.com/machine-learning-k-nearest-neighbors-knn/

# %%
# Applying K-Nearest Neighbours Algorithm
# Iterating for different values of K
# Training on the entire set to find the correct value of K 
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier


knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X,Y)
Y_pred = knn.predict(X)
# to evaluate the accuracy of the model
print(metrics.accuracy_score(Y, Y_pred))
# Out:
# 0.656896551724138

# %%
# Applying Random Forests Classifier
# https://towardsdatascience.com/an-implementation-and-explanation-of-the-random-forest-in-python-77bf308a9b76

from sklearn.ensemble import RandomForestClassifier

# Creating a Random Foresr with 100 trees
model = RandomForestClassifier(n_estimators=10,bootstrap=True,max_features ='sqrt')

model.fit(X,Y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
# Actual Predcitons
Y_pred = model.predict(X)
# Predictions for each class
Y_probs = model.predict_proba(X)

print(Y_pred)
print(Y_probs)
# Out:
# [3 1 4 5 2 4 2 4 4 2 3 5 4 2 2 4 3 1 3 1 1 5 5 4 3 2 2 5 4 1 4 5 1 5 4 1 5
#  5 2 4 4 1 5 4 2 1 4 3 3 1 4 5 5 5 1 2 5 3 3 3 5 3 5 4 2 5 1 3 3 3 3 3 3 4
#  3 4 3 3 4 5 4 1 1 2 3 2 4 1 4 4 2 4 4 3 1 3 5 2 1 3 1 4 1 5 1 4 3 3 4 2 5
#  4 5 2 2 1 3 2 4 5 1 1 1 5 3 1 4 4 4 3 4 3 3 5 3 4 3 3 3 1 1 2 3 1 3 5 4 3
#  5 3 1 5 5 1 5 3 4 5 3 4 3 3 3 2 2 4 4 5 4 1 1 1 4 1 2 4 3 1 5 2 1 1 5 5 4
#  2 1 5 1 2 1 4 1 2 1 1 4 4 1 3 2 5 3 4 3 3 3 4 2 2 3 5 5 5 1 2 2 5 4 5 4 4
#  3 1 2 1 2 2 2 2 5 1 3 5 1 5 2 2 4 4 1 4 5 3 3 3 1 5 1 4 3 1 1 5 3 5 4 2 3
#  4 3 1 4 2 1 3 4 5 2 4 4 5 3 1 2 4 1 3 3 3 4 5 5 5 2 1 1 3 5 5 5 5 2 4 2 3
#  3 4 3 4 2 3 3 1 1 5 3 3 5 1 3 3 2 3 2 2 1 1 5 5 4 3 3 3 5 4 4 5 2 3 3 2 2
#  4 2 3 4 4 2 5 2 1 1 5 2 4 2 1 3 2 2 4 1 2 3 3 2 4 4 1 1 1 2 1 1 2 1 4 4 5
#  3 3 4 1 4 3 3 2 1 4 2 1 3 5 1 3 4 4 5 1 5 5 1 4 4 1 3 2 1 5 1 3 1 3 1 1 1
#  3 4 3 5 3 1 3 3 5 2 4 1 4 2 4 1 4 1 3 3 5 2 1 4 3 4 1 2 1 5 4 2 1 4 5 3 4
# ...

# %%
Y
# Out:
# 0      3
# 1      1
# 2      4
# 3      5
# 4      2
# 5      4
# 6      2
# 7      4
# 8      4
# 9      2
# 10     3
# 11     5
# 12     4
# 13     2
# 14     2
# 15     4
# 16     3
# 17     1
# 18     3
# 19     1
# 20     1
# 21     5
# 22     5
# 23     4
# 24     3
# 25     2
# 26     2
# 27     5
# 28     4
# 29     1
#       ..
# 550    1
# 551    5
# 552    1
# 553    1
# 554    2
# 555    2
# 556    1
# 557    4
# 558    2
# 559    2
# 560    5
# 561    5
# 562    4
# 563    4
# 564    5
# 565    2
# 566    3
# 567    1
# 568    1
# 569    1
# 570    4
# 571    5
# 572    3
# 573    2
# 574    5
# 575    3
# 576    1
# 577    1
# 578    2
# 579    1
# Name: hearts, Length: 580, dtype: int64

# %%
# After Training on the entire data
# We are training on the entire data so that we can tune the parameters
print(metrics.accuracy_score(Y, Y_pred))
# Out:
# 0.9844827586206897

# %%
# Creating a test train split

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20,random_state=10)

# %%
from sklearn.neighbors import KNeighborsClassifier

train_acc = []
test_acc = []
for i in range(1,20):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,Y_train)
    acc_train = knn.score(X_train,Y_train)
    train_acc.append(acc_train)
    acc_test = knn.score(X_test,Y_test)
    test_acc.append(acc_test)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
train_score,=plt.plot(range(1,20),train_acc,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='green', markersize=5)
test_score,=plt.plot(range(1,20),test_acc,color='red',linestyle='dashed',  marker='o',
         markerfacecolor='blue', markersize=5)
plt.legend( [train_score, test_score],["Train Accuracy", "Test Accuracy"])
plt.title('Accuracy vs K neighbors')
plt.xlabel('K neighbors')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
Y_pred = model.predict(X_test)
Y_probs = model.predict_proba(X_test)[:,1]

Y_pred
# Out:
# array([3, 2, 1, 3, 1, 5, 1, 1, 2, 2, 1, 1, 1, 2, 4, 1, 3, 1, 1, 3, 3, 3,
#        3, 4, 4, 4, 4, 3, 1, 4, 5, 1, 3, 4, 3, 1, 4, 1, 4, 5, 2, 5, 3, 2,
#        3, 3, 3, 4, 2, 2, 1, 4, 1, 1, 4, 4, 1, 1, 1, 3, 1, 3, 3, 3, 4, 4,
#        5, 1, 1, 3, 3, 1, 3, 1, 3, 4, 2, 1, 3, 1, 3, 1, 2, 1, 2, 3, 4, 5,
#        2, 1, 1, 4, 1, 2, 4, 3, 2, 4, 1, 2, 5, 2, 4, 1, 2, 3, 2, 1, 2, 3,
#        4, 2, 4, 5, 2, 1])

# %%
# Using Decision tree

rf = RandomForestClassifier( max_depth=10,random_state=7) 
rf.fit(X_train, Y_train)
sc_train = rf.score(X_train,Y_train)
sc_test = rf.score(X_test,Y_test)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
sc_train
# Out:
# 0.959051724137931

# %%
sc_test
# Out:
# 0.3879310344827586

# %%
# import the class
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression()

# fit the model with data
logreg.fit(X, Y)

# predict the response values for the observations in X
logreg.predict(X)

# store the predicted response values
Y_pred = logreg.predict(X)

from sklearn import metrics

print(metrics.accuracy_score(Y, Y_pred))
# Out:
# 0.32241379310344825
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
from sklearn.ensemble import RandomForestClassifier

score_train_RF = []
score_test_RF = []

for i in range(5,20,1):
    rf = RandomForestClassifier(n_estimators = 100, max_depth=i)
    rf.fit(X_train, Y_train)
    sc_train = rf.score(X_train,Y_train)
    score_train_RF.append(sc_train)
    sc_test = rf.score(X_test,Y_test)
    score_test_RF.append(sc_test)

# %%
plt.figure(figsize=(10,6))
train_score,=plt.plot(range(5,20,1),score_train_RF,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='green', markersize=5)
test_score,=plt.plot(range(5,20,1),score_test_RF,color='red',linestyle='dashed',  marker='o',
         markerfacecolor='blue', markersize=5)
plt.legend( [train_score,test_score],["Train Score","Test Score"])
plt.title('Fig4. Score vs. No. of Trees')
plt.xlabel('No. of Trees')
plt.ylabel('Score')
# Out:
# Text(0, 0.5, 'Score')
